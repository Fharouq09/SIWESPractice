# %%
# import the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# importing the dataset and extracting the Independent and dependent variables

company = pd.read_csv('C:/Users/LaraBeey/Desktop/Practice/1000_Companies.csv')
X = company.iloc[:, :-1].values
y = company.iloc[:, 4].values

company.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Calculate the correlation matrix for numeric columns
correlation_matrix = company.corr(numeric_only=True)

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#Splitting the dataset into thr Training set and Test set
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression

X = [2]  # Your feature matrix
y = [2]  # Your target variable

model = LinearRegression()

# Check the number of samples in X and y
if len(X) != len(y):
    raise ValueError("Number of samples in X and y must be the same.")
cross_val_score = cross_val_score(model, X, y, cv=5)

# Print the cross-validation scores
print("Cross-Validation Scores:", cross_val_score)
print("Mean CV Score:", cross_val_score.mean())
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
# Encoding categorical data

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()

X = np.array([["A", 1],
              ["B", 2],
              ["A", 3],
              ["C", 1]])

X[:, 0] = labelencoder.fit_transform(X[:, 0])
column_transformer = ColumnTransformer(
    transformers=[('encoder', OneHotEncoder(), [1])],  # [3] is the index of the categorical column
    remainder='passthrough'  # Keep the remaining columns as they are
)

# Apply the transformations
X = column_transformer.fit_transform(X)

onehotencoder = OneHotEncoder()
X = onehotencoder.fit_transform(X).toarray()
X = np.array(X)

# %%
X = X[:, 1:]

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.3.0

# %%
#Splitting the dataset into the Training set and Test set

from sklearn.model_selection import train_test_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 3
#       1 #Splitting the dataset into the Training set and Test set
# ----> 3 from sklearn.model_selection import train_test_test_split
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
#
# ImportError: cannot import name 'train_test_test_split' from 'sklearn.model_selection' (C:\Users\LaraBeey\anaconda3\Lib\site-packages\sklearn\model_selection\__init__.py)
