# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("GPA and SAT dataset.csv")

# %%
data
# Out:
#       GPA  SAT Score
# 0   2.714       1480
# 1   3.418       1620
# 2   4.325       2070
# 3   2.552       1200
# 4   2.634       1300
# 5   3.352       1310
# 6   2.758        880
# 7   4.231       2230
# 8   2.975       1180
# 9   3.839       1900
# 10  3.788       1480
# 11  2.133        720
# 12  1.136        760
# 13  3.053       1490
# 14  4.074       1940
# 15  3.515       1400
# 16  1.980       1170
# 17  2.788       1410
# 18  3.681       1290
# 19  4.141       2390
# 20  3.130       1410
# 21  2.311       1090
# 22  2.421       1120
# 23  1.631        940
# 24  3.472       1460
# 25  1.370        980
# 26  2.498       1460
# 27  3.890       1880
# 28  3.952       2250
# 29  2.254       1480
# 30  3.193       1400
# 31  2.835       1390
# 32  3.287       1350
# 33  3.587       1850

# %%
data.describe()
# Out:
#             GPA    SAT Score
# count  34.00000    34.000000
# mean    3.02700  1449.411765
# std     0.82431   415.385481
# min     1.13600   720.000000
# 25%     2.51150  1185.000000
# 50%     3.09150  1405.000000
# 75%     3.65750  1587.500000
# max     4.32500  2390.000000

# %%
y = data['GPA']
x1 = data['SAT Score']

# %%
plt.scatter(x1,y)
plt.xlabel('SAT Score', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.694
# Model:                            OLS   Adj. R-squared:                  0.685
# Method:                 Least Squares   F-statistic:                     72.60
# Date:                Sun, 05 Nov 2023   Prob (F-statistic):           9.76e-10
# Time:                        00:07:11   Log-Likelihood:                -21.032
# No. Observations:                  34   AIC:                             46.06
# Df Residuals:                      32   BIC:                             49.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6307      0.292      2.158      0.039       0.035       1.226
# SAT Score      0.0017      0.000      8.521      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                        0.594   Durbin-Watson:                   2.185
# Prob(Omnibus):                  0.743   Jarque-Bera (JB):                0.667
# Skew:                          -0.102   Prob(JB):                        0.716
# Kurtosis:                       2.345   Cond. No.                     5.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0.275
fig = plt.plot(x1,yhat,lw=4, c='orange', label='regression line')
plt.xlabel('SAT Score', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0
fig = plt.plot(x1,yhat,lw=4, c='green', label='regression line')
plt.xlabel('SAT Score', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.xlim(0)
plt.ylim(0)
plt.show()
